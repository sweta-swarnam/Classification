# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import warnings
#warnings.filterwarnings('ignore',category=Deprecationwarning)
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import  matplotlib.pyplot as plt

# %%
pip install nltk==3.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install vaderSentiment
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade vaderSentiment
# Out:
# Requirement already up-to-date: vaderSentiment in c:\users\win\anaconda3\lib\site-packages (3.3.2)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x03845810>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/vadersentiment/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x03845670>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/vadersentiment/
# ...

# %%
User=["Social media user","Donot use social media"]
no= [1370000000,900000000]

# %%
plt.pie(no,labels=User,radius=1,autopct="%0.2f%%",shadow=True)
plt.title("SOCIAL MEDIA USER IN INDIA",fontsize=17)
# Out:
# Text(0.5, 1.0, 'SOCIAL MEDIA USER IN INDIA')

# %%
Source=["Facebook","Instagram","Twitter","Whatsapp","Snapchat","Linkedin","Youtube",]
No=[174,156,68,90,99,130,182,]

# %%
#c=["blue","olive","maroon","teal","purple","Orange","green",]

# %%
plt.bar(Source,No,0.7,color=c)#vertical
#plt.barh(Sentiment,Comment,0.7,color=c)# horizontal
plt.ylabel("No in Million of Student",fontsize=15)
plt.xlabel("Source of Social Media",fontsize=15)
plt.title("SOURCE OF SOCIAL MEDIA USE BY STUDENTS IN INDIA",fontsize=17)
plt.show()

# %%
plt.rcParams['figure.figsize']= (10,6)

# %%
plt.barh(Sentiment,Comment,0.7,color=c)# horizontal
plt.xlabel("No of Comments",fontsize=15)
plt.ylabel("Sentiment",fontsize=15)
plt.title("SONY MUSIC INDIA",fontsize=17)
plt.show()

# %%
X=[84,95,32,20]
y=["Facebook","Youtube","Google Plus","Twitter"]

# %%
plt.ylabel("No in Million",fontsize=15)
plt.xlabel("Source",fontsize=15)
plt.title("SOURCE OF SOCIAL MEDIA",fontsize=17)
center=5
plt.pie(X,labels=y,radius=1)
plt.pie(center,radius=.5,colors="w",autopct="%0.2f%%",shadow=True)
plt.show()
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
df=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\FB.csv",encoding="latin-1")

# %%
df
# Out:
#                                                  Good
# 0   Facebook may help students learn better by tra...
# 1   They gain skills through peer learning as well...
# 2   Facebook requires students to express themselv...
# 3   we stifle learners with spelling and grammar r...
# 4   schools who restrict or block Facebook are mis...
# 5   Students who use Facebook and hit the books si...
# 6   Facebook-using students also made less money d...
# 7   Have students follow news feeds relevant to th...
# 8   You can find your old friends whom you had los...
# 9    Facebook is good source of learning for student.
# 10   Facebook is one of the largest social media p...
# 11  our audience of Facebook 'likes' can be a grea...
# 12  University students who used a Facebook group ...
# 13  Facebook helps the students in gaining knowled...
# 14  Facebook as a learning environment facilitates...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='khaki',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=80,
        scale=4,
        random_state=1
    ).generate(str(df))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('FACEBOOK REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(df["Good"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-d7a1323ed711> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(df["Good"])
#
# <ipython-input-145-d7a1323ed711> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(df["Good"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
df1=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\wtapp.csv",encoding="latin-1")

# %%
df1
# Out:
#                                                  Good
# 0   Whatsapp application is useful for keeping in ...
# 1   It helps us provide our students with improved...
# 2   Similar instant messaging solutions have been ...
# 3   WhatsApp use for education and determine the o...
# 4   a few students have expressed adverse opinions...
# 5    use of WhatsApp in education process be encou...
# 6   The high number of people joining social netwo...
# 7   development of mobile versions Whatsapp of the...
# 8   This process, which started by commonly used w...
# 9   long time for WhatsApp to influence the learni...
# 10  WhatsApp application is a smartphone applicati...
# 11  WhatsApp is currently the most popular messagi...
# 12  Prior WhatsApp work, as discussed in more deta...
# 13  WhatsApp messages and conversation groups by c...
# 14  WhatsApp messages from 111 students between th...
# 15  WhatsApp usage across people of different gend...
# ...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='green',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=90,
        scale=4,
        random_state=1
    ).generate(str(df1))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('WHATSAPP REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(df["Good"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-b17642c2ac25> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(df["Good"])
#
# <ipython-input-149-b17642c2ac25> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(df["Good"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
df2=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\insta2.csv",encoding="latin-1")

# %%
df2
# Out:
#                                                  Good
# 0    Teachers can also use Instagram to help students
# 1   You can post homework and project reminders, a...
# 2   Instagram is also a great way to encourage cla...
# 3   Instagram that were accompanied by the hashtag...
# 4   Teacher were also pictures of objects at cerem...
# 5   Instagram memorializing is distinguished by be...
# 6   Teacher the Instagram feeds of 27 professional...
# 7   Instagram analyzed the personality features ag...
# 8   text-based social media alone did nothing to r...
# 9           Instagram is an entirely visual platform.
# 10   Instagram's sole purpose is to enable users t...
# 11  Teacher can easy way to do this is to research...
# 12  Instagram helps students form emotional intell...
# 13  Teachers can conduct a few classroom activitie...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='peru',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=100,
        scale=4,
        random_state=1
    ).generate(str(df2))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('INSTAGRAM REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(df["Good"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-d3f7970f3d73> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(df["Good"])
#
# <ipython-input-115-d3f7970f3d73> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(df["Good"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
df3=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\Twitter.csv",encoding="latin-1")

# %%
df3
# Out:
#                                                  Good
# 0   Twitter allows you to: easily promote your res...
# 1   or example by providing links to your blog sto...
# 2   keep up-to-date with the latest news and devel...
# 3   Twitter can be use to extarat tweets to do ana...
# 4    Twitter as an educational tool has explored t...
# 5   Twitter, online microblogging service for dist...
# 6   students should know about, you can use Twitte...
# 7   Students receive instant notifications, and th...
# 8   One of the most exciting ways teachers are usi...
# 9   Teachers can also assign homework in other sub...
# 10  Twitter can be used to teach media and informa...
# 11   Twitter use variables, including positive stu...
# 12  Twitter in order to work on collaborative assi...
# 13  regular news updates through following, there ...
# 14  regular news updates through following, there ...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='violet',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=100,
        scale=4,
        random_state=1
    ).generate(str(df3))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('TWITTER REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(df["Good"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-59d389cec601> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(df["Good"])
#
# <ipython-input-125-59d389cec601> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(df["Good"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
df4=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\snap.csv",encoding="latin-1")

# %%
df4
# Out:
#                                                  snap
# 0   Snapchat use say the app makes them feel happy...
# 1   Snapchat is a popular messaging app that lets ...
# 2   Snapchat recently partnered with Murphy Resear...
# 3   learn more about the apps they use, when they ...
# 4   Snapchat is designed around the idea of auto-d...
# 5   Young adults in this study were asked how Snap...
# 6                Snapchat Q&A is one of my favorites.
# 7   There are multiple ways that  can use Snapchat...
# 8    can feel by the end of a Snapchat Q&A that ar...
# 9   Snapchat allows to transmit what would be lost...
# 10  Snapchat to get students engaging with profess...
# 11  compilation of Snapchat user and usage statistics
# 12  Snapchat for connecting with friends and brand...
# 13              Snapchat's tone is candid and casual.
# 14               77% of college students use Snapchat
# 15  50% of college students using Snapchat to comm...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='crimson',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=80,
        scale=4,
        random_state=1
    ).generate(str(df4))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('SNAPCHART REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(df["snap"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-f33f4fe563dc> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(df["snap"])
#
# <ipython-input-141-f33f4fe563dc> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(df["snap"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
d1=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\linkd.csv",encoding="latin-1")

# %%
d1
# Out:
#                                                  snap
# 0   LinkedIn is the world's largest professional n...
# 1    biggest benefits LinkedIn offers college stud...
# 2   visiting company, pages, you can conduct a res...
# 3   Students and jobseekers will be able to see th...
# 4   email alerts to receive notifications of recom...
# 5   can find your friends, co-workers, colleagues,...
# 6          never a tough job connecting with them all
# 7   you can even import your email list to find ou...
# 8   One of the biggest benefits LinkedIn offers co...
# 9   this kind of company research on LinkedIn can ...
# 10  LinkedIn also offers a feature through which y...
# 11  College students too can try to get as many re...
# 12  College students can also use LinkedIn to netw...
# 13  his type of networking gives you a wonderful o...
# 14           LinkedIn is a global networking platform
# 15  can get a lot of benefits by networking on thi...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='grey',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=80,
        scale=4,
        random_state=1
    ).generate(str(d1))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('LINKEDIN REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(d1["snap"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-169-781f2e7aae69> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(d1["snap"])
#
# <ipython-input-169-781f2e7aae69> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(d1["snap"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
d2=pd.read_csv("E:\SEM -3\SMA\DATA SET 6\youtube.csv",encoding="latin-1")

# %%
d2
# Out:
#                                               Youtube
# 0   YouTube videos to student  eLearning course is...
# 1   YouTube video, student can encourage online di...
# 2   YouTube makes it available throughout the YouT...
# 3   YouTube is available on all devices and allows...
# 4   YouTube as a virtual library to support studen...
# 5   walking your audience through a process via a ...
# 6   develop and enhance their visual literacy and ...
# 7   interested in learning how to create student o...
# 8   Youtube interested in learning how to create s...
# 9   YouTube gives eLearning professionals the powe...
# 10  YouTube videos that recap information they've ...
# 11  YouTube videos can illustrate a complex concep...
# 12  YouTube privacy settings can be customized for...
# 13  YouTube videos, and then to discuss the topic ...
# 14  Students enjoy spending their classroom time w...
# 15  improve their listening comprehension and pron...
# ...

# %%
stopwords = set(STOPWORDS)
def Mywordcloud(data,title="sevice"):
    wordcloud = WordCloud(
        background_color='sienna',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=80,
        scale=4,
        random_state=1
    ).generate(str(d2))
    
    fig = plt.figure(1, figsize=(12,15))
    plt.axis("on")
    if title:
        fig.suptitle(title, fontsize=25)
        fig.subplots_adjust(top=3.2)
        
        plt.imshow(wordcloud)
        plt.title('YOUTUBE REVIEW FOR STUDY PURPOSE',size=20)
        plt.show()
        
        show_wordcloud()
        
Mywordcloud(d2["Youtube"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-0a16409e00b3> in <module>
#      22         show_wordcloud()
#      23
# ---> 24 Mywordcloud(d2["Youtube"])
#
# <ipython-input-174-0a16409e00b3> in Mywordcloud(data, title)
#      20         plt.show()
#      21
# ---> 22         show_wordcloud()
#      23
#      24 Mywordcloud(d2["Youtube"])
#
# NameError: name 'show_wordcloud' is not defined

# %%
Source=["SCHOOL","HSC","BACHELOR","MASTER","OTHER"]
stud=[11.6,4.5,13.7,5.9,17]

# %%
plt.pie(stud,labels=Source,radius=1,autopct="%0.2f%%",shadow=True)
plt.title("SOCIAL MEDIA USES BY STUDENT FOR STUDY")
# Out:
# Text(0.5, 1.0, 'SOCIAL MEDIA USES BY STUDENT FOR STUDY')

# %%
yr=["2015","2016","2017","2018","2019","2020"]
view=[42,46,32,35,32,40]

# %%
fig=plt.figure()
#ax=fig.add_axes([0,0,20,20])
ax.set_title("STUDENT USES SOCIAL MEDIA")
ax.set_xlabel('yr')
ax.set_ylabel('view')
plt.plot(yr,view,'-.go')
plt.xlabel('year',fontsize=15)
plt.ylabel('No in Million',fontsize=15)
plt.title('STUDENT USES SOCIAL MEDIA IN LAST 5 YEARS',fontsize=20)
# Out:
# Text(0.5, 1.0, 'STUDENT USES SOCIAL MEDIA IN LAST 5 YEARS')

# %%
yr=["2015","2016","2017","2018","2019","2020"]
time=[109,126,135,144,153,175]

# %%
c1=["magenta","peru","blue","orange","green","maroon"]

# %%
plt.barh(yr,time,0.7,color=c1)
plt.xlabel("TIME IN MINUTES",fontsize=15)
plt.ylabel("YEAR",fontsize=15)
plt.title("AVG TIME SPEND ON SOCIAL MEDIA BY STUDENTS IN 6 YEARS",fontsize=17)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
yr1= [23,20,17,15,11,9,27]
yr2=[27,22,13,19,18,7,13]
yr3=[40,17,22,10,22,44,19]
x = numpy.arange(len(yr1))

# %%
plt.stackplot(x,yr1,yr2,yr3,colors=['green','red','yellow'])
plt.title("AVG TIME SPEND ON SOCIAL MEDIA BY STUDENT")
plt.xlabel('Source')
plt.ylabel('Avg Time Per Day in Mintues')
plt.xticks(x,['facebook','twitter','youtube','linkedin','instagram','whatsapp','snapchat'])
# Out:
# ([<matplotlib.axis.XTick at 0xc84e650>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %%
Source=['Facebook','Twitter','Youtube','Linkedin','Instagram','Whatsapp','Snapchat']
yr3=[40,17,22,10,22,44,19]

# %%
#c2=["crimson","crimson","crimson","crimson","crimson","crimson"]

# %%
plt.bar(Source,yr3,0.8,color="crimson")
plt.xlabel("Sources",fontsize=15)
plt.ylabel("Avg Time Per Day in Mintues",fontsize=15)
plt.title("AVG TIME SPEND ON SOCIAL MEDIA BY STUDENT IN 2020",fontsize=17)
plt.show()

# %%
plt.rcParams['figure.figsize']= (10,6)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
men=[23,12,13,8]
women=[11,9,17,9]
plt.hist([men,women],bins=[8,10,12,14],rwidth=1.9,color=["blue","red"],label=['BOYS','GIRLS'])
plt.legend()
